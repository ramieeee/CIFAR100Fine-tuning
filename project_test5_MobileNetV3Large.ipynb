# %%
# MobileNet_V3 전이학습

from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v3 import decode_predictions
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
import numpy as np

# %%
import tensorflow as tf

# %%
##### 전이학습 시작 #####

# %%
(train_images_raw, train_labels_raw), (test_images, test_labels) = tf.keras.datasets.cifar100.load_data(label_mode='coarse')

# %%
def preprocess_image_input(input_images):
  input_images = input_images.astype('float32')
  output_images = preprocess_input(input_images)
  return output_images

# %%
train_images = train_images_raw[:45000]
train_labels = train_labels_raw[:45000]

# %%
valid_images = train_images_raw[40000:]
valid_labels = train_labels_raw[40000:]

# %%
train_X = preprocess_image_input(train_images)
valid_X = preprocess_image_input(valid_images)

# %%
feature_extractor = MobileNetV3Large(input_shape=(224,224,3),
                                                include_top=False,
                                                weights='imagenet')

# %%
# CNN 전체 학습
feature_extractor.trainable = True

# %%
feature_extractor.summary()
# Out:
# Model: "MobilenetV3large"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_2 (Rescaling)        (None, 224, 224, 3)  0           ['input_5[0][0]']
#
#  Conv (Conv2D)                  (None, 112, 112, 16  432         ['rescaling_2[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 112, 112, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add_56 (TFOpL  (None, 112, 112, 16  0          ['Conv/BatchNorm[0][0]']
#  ambda)                         )
#
#  re_lu_78 (ReLU)                (None, 112, 112, 16  0           ['tf.__operators__.add_56[0][0]']
#                                 )
#
#  tf.math.multiply_56 (TFOpLambd  (None, 112, 112, 16  0          ['re_lu_78[0][0]']
#  a)                             )
#
#  multiply_40 (Multiply)         (None, 112, 112, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply_56[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 112, 112, 16  144        ['multiply_40[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv/depthwise/BatchN  (None, 112, 112, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
#  re_lu_79 (ReLU)                (None, 112, 112, 16  0           ['expanded_conv/depthwise/BatchNo
#                                 )                                rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 112, 112, 16  256        ['re_lu_79[0][0]']
#                                 )
#
#  expanded_conv/project/BatchNor  (None, 112, 112, 16  64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         )
#
#  expanded_conv/Add (Add)        (None, 112, 112, 16  0           ['multiply_40[0][0]',
#                                 )                                 'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 112, 112, 64  1024       ['expanded_conv/Add[0][0]']
#  )                              )
#
#  expanded_conv_1/expand/BatchNo  (None, 112, 112, 64  256        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_80 (ReLU)                (None, 112, 112, 64  0           ['expanded_conv_1/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 113, 113, 64  0          ['re_lu_80[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_1/depthwise (Dep  (None, 56, 56, 64)  576         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 56, 56, 64)  256         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_81 (ReLU)                (None, 56, 56, 64)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 56, 56, 24)  1536        ['re_lu_81[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 56, 56, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 56, 56, 72)  1728        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 56, 56, 72)  288         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_82 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 56, 56, 72)  648         ['re_lu_82[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 56, 56, 72)  288         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_83 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 56, 56, 24)  1728        ['re_lu_83[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 56, 56, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 56, 56, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 56, 56, 72)  1728        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 56, 56, 72)  288         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_84 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 59, 59, 72)  0           ['re_lu_84[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 28, 28, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 28, 28, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_85 (ReLU)                (None, 28, 28, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_85[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_57 (TFOpL  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_86 (ReLU)                (None, 1, 1, 72)     0           ['tf.__operators__.add_57[0][0]']
#
#  tf.math.multiply_57 (TFOpLambd  (None, 1, 1, 72)    0           ['re_lu_86[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, 28, 28, 72)  0           ['re_lu_85[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_57[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 28, 28, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 28, 28, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 28, 28, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_87 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 28, 28, 120)  3000       ['re_lu_87[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 28, 28, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_88 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_88[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_58 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_89 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_58[0][0]']
#
#  tf.math.multiply_58 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_89[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, 28, 28, 120)  0          ['re_lu_88[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_58[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 28, 28, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 28, 28, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 28, 28, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 28, 28, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_90 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 28, 28, 120)  3000       ['re_lu_90[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 28, 28, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_91 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_91[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_59 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_92 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_59[0][0]']
#
#  tf.math.multiply_59 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_92[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, 28, 28, 120)  0          ['re_lu_91[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_59[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 28, 28, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 28, 28, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 28, 28, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 28, 28, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_60 (TFOpL  (None, 28, 28, 240)  0          ['expanded_conv_6/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_93 (ReLU)                (None, 28, 28, 240)  0           ['tf.__operators__.add_60[0][0]']
#
#  tf.math.multiply_60 (TFOpLambd  (None, 28, 28, 240)  0          ['re_lu_93[0][0]']
#  a)
#
#  multiply_41 (Multiply)         (None, 28, 28, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_60[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 29, 29, 240)  0          ['multiply_41[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 14, 14, 240)  2160       ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 14, 14, 240)  960        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_61 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_6/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_94 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_61[0][0]']
#
#  tf.math.multiply_61 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_94[0][0]']
#  a)
#
#  multiply_42 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_61[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 14, 14, 80)  19200       ['multiply_42[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 14, 14, 200)  16000      ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 14, 14, 200)  800        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_62 (TFOpL  (None, 14, 14, 200)  0          ['expanded_conv_7/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_95 (ReLU)                (None, 14, 14, 200)  0           ['tf.__operators__.add_62[0][0]']
#
#  tf.math.multiply_62 (TFOpLambd  (None, 14, 14, 200)  0          ['re_lu_95[0][0]']
#  a)
#
#  multiply_43 (Multiply)         (None, 14, 14, 200)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_62[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 14, 14, 200)  1800       ['multiply_43[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 14, 14, 200)  800        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_63 (TFOpL  (None, 14, 14, 200)  0          ['expanded_conv_7/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_96 (ReLU)                (None, 14, 14, 200)  0           ['tf.__operators__.add_63[0][0]']
#
#  tf.math.multiply_63 (TFOpLambd  (None, 14, 14, 200)  0          ['re_lu_96[0][0]']
#  a)
#
#  multiply_44 (Multiply)         (None, 14, 14, 200)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_63[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 14, 14, 80)  16000       ['multiply_44[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 14, 14, 184)  14720      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 14, 14, 184)  736        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_64 (TFOpL  (None, 14, 14, 184)  0          ['expanded_conv_8/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_97 (ReLU)                (None, 14, 14, 184)  0           ['tf.__operators__.add_64[0][0]']
#
#  tf.math.multiply_64 (TFOpLambd  (None, 14, 14, 184)  0          ['re_lu_97[0][0]']
#  a)
#
#  multiply_45 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_64[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 14, 14, 184)  1656       ['multiply_45[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 14, 14, 184)  736        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_65 (TFOpL  (None, 14, 14, 184)  0          ['expanded_conv_8/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_98 (ReLU)                (None, 14, 14, 184)  0           ['tf.__operators__.add_65[0][0]']
#
#  tf.math.multiply_65 (TFOpLambd  (None, 14, 14, 184)  0          ['re_lu_98[0][0]']
#  a)
#
#  multiply_46 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_65[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 14, 14, 80)  14720       ['multiply_46[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 14, 14, 184)  14720      ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 14, 14, 184)  736        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_66 (TFOpL  (None, 14, 14, 184)  0          ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_99 (ReLU)                (None, 14, 14, 184)  0           ['tf.__operators__.add_66[0][0]']
#
#  tf.math.multiply_66 (TFOpLambd  (None, 14, 14, 184)  0          ['re_lu_99[0][0]']
#  a)
#
#  multiply_47 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_66[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 14, 14, 184)  1656       ['multiply_47[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 14, 14, 184)  736        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_67 (TFOpL  (None, 14, 14, 184)  0          ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_100 (ReLU)               (None, 14, 14, 184)  0           ['tf.__operators__.add_67[0][0]']
#
#  tf.math.multiply_67 (TFOpLambd  (None, 14, 14, 184)  0          ['re_lu_100[0][0]']
#  a)
#
#  multiply_48 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_67[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 14, 14, 80)  14720       ['multiply_48[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 14, 14, 480)  38400      ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 14, 14, 480)  1920       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_68 (TFOpL  (None, 14, 14, 480)  0          ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_101 (ReLU)               (None, 14, 14, 480)  0           ['tf.__operators__.add_68[0][0]']
#
#  tf.math.multiply_68 (TFOpLambd  (None, 14, 14, 480)  0          ['re_lu_101[0][0]']
#  a)
#
#  multiply_49 (Multiply)         (None, 14, 14, 480)  0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_68[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 14, 14, 480)  4320       ['multiply_49[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 14, 14, 480)  1920       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_69 (TFOpL  (None, 14, 14, 480)  0          ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_102 (ReLU)               (None, 14, 14, 480)  0           ['tf.__operators__.add_69[0][0]']
#
#  tf.math.multiply_69 (TFOpLambd  (None, 14, 14, 480)  0          ['re_lu_102[0][0]']
#  a)
#
#  multiply_50 (Multiply)         (None, 14, 14, 480)  0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_69[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   0           ['multiply_50[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   57720       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
# ...
#
#  expanded_conv_13/expand (Conv2  (None, 7, 7, 960)   153600      ['expanded_conv_12/project/BatchN
#  D)                                                              orm[0][0]']
#
#  expanded_conv_13/expand/BatchN  (None, 7, 7, 960)   3840        ['expanded_conv_13/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_77 (TFOpL  (None, 7, 7, 960)   0           ['expanded_conv_13/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_110 (ReLU)               (None, 7, 7, 960)    0           ['tf.__operators__.add_77[0][0]']
#
#  tf.math.multiply_77 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_110[0][0]']
#  a)
#
#  multiply_55 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_13/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_77[0][0]']
#
#  expanded_conv_13/depthwise (De  (None, 7, 7, 960)   24000       ['multiply_55[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_13/depthwise/Bat  (None, 7, 7, 960)   3840        ['expanded_conv_13/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_78 (TFOpL  (None, 7, 7, 960)   0           ['expanded_conv_13/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_111 (ReLU)               (None, 7, 7, 960)    0           ['tf.__operators__.add_78[0][0]']
#
#  tf.math.multiply_78 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_111[0][0]']
#  a)
#
#  multiply_56 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_13/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_78[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_56[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_13/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_13/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_13/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_79 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_13/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_112 (ReLU)               (None, 1, 1, 960)    0           ['tf.__operators__.add_79[0][0]']
#
#  tf.math.multiply_79 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_112[0][0]']
#  a)
#
#  expanded_conv_13/squeeze_excit  (None, 7, 7, 960)   0           ['multiply_56[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_79[0][0]']
#
#  expanded_conv_13/project (Conv  (None, 7, 7, 160)   153600      ['expanded_conv_13/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_13/project/Batch  (None, 7, 7, 160)   640         ['expanded_conv_13/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_13/Add (Add)     (None, 7, 7, 160)    0           ['expanded_conv_12/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_13/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_14/expand (Conv2  (None, 7, 7, 960)   153600      ['expanded_conv_13/Add[0][0]']
#  D)
#
#  expanded_conv_14/expand/BatchN  (None, 7, 7, 960)   3840        ['expanded_conv_14/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_80 (TFOpL  (None, 7, 7, 960)   0           ['expanded_conv_14/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_113 (ReLU)               (None, 7, 7, 960)    0           ['tf.__operators__.add_80[0][0]']
#
#  tf.math.multiply_80 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_113[0][0]']
#  a)
#
#  multiply_57 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_14/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_80[0][0]']
#
#  expanded_conv_14/depthwise (De  (None, 7, 7, 960)   24000       ['multiply_57[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_14/depthwise/Bat  (None, 7, 7, 960)   3840        ['expanded_conv_14/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_81 (TFOpL  (None, 7, 7, 960)   0           ['expanded_conv_14/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_114 (ReLU)               (None, 7, 7, 960)    0           ['tf.__operators__.add_81[0][0]']
#
#  tf.math.multiply_81 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_114[0][0]']
#  a)
#
#  multiply_58 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_14/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_81[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_58[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_14/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_14/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_14/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_82 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_14/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_115 (ReLU)               (None, 1, 1, 960)    0           ['tf.__operators__.add_82[0][0]']
#
#  tf.math.multiply_82 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_115[0][0]']
#  a)
#
#  expanded_conv_14/squeeze_excit  (None, 7, 7, 960)   0           ['multiply_58[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_82[0][0]']
#
#  expanded_conv_14/project (Conv  (None, 7, 7, 160)   153600      ['expanded_conv_14/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_14/project/Batch  (None, 7, 7, 160)   640         ['expanded_conv_14/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_14/Add (Add)     (None, 7, 7, 160)    0           ['expanded_conv_13/Add[0][0]',
#                                                                   'expanded_conv_14/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 7, 7, 960)    153600      ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 7, 7, 960)   3840        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_83 (TFOpL  (None, 7, 7, 960)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_116 (ReLU)               (None, 7, 7, 960)    0           ['tf.__operators__.add_83[0][0]']
#
#  tf.math.multiply_83 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_116[0][0]']
#  a)
#
#  multiply_59 (Multiply)         (None, 7, 7, 960)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_83[0][0]']
#
# ==================================================================================================
# Total params: 2,996,352
# Trainable params: 2,971,952
# Non-trainable params: 24,400
# __________________________________________________________________________________________________

# %%
inputs = tf.keras.Input(shape=(32, 32, 3))
x = tf.keras.layers.UpSampling2D(size=(7,7))(inputs)
x = feature_extractor(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(1024, activation="relu")(x)
x = tf.keras.layers.Dense(1024, activation="relu")(x)
x = tf.keras.layers.Dense(512, activation="relu")(x)
# output classification count: 20
outputs = tf.keras.layers.Dense(20, activation="softmax", name="classification")(x)

# %%
model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  up_sampling2d_2 (UpSampling  (None, 224, 224, 3)      0
#  2D)
#
#  MobilenetV3large (Functiona  (None, 7, 7, 960)        2996352
#  l)
#
#  global_average_pooling2d_2   (None, 960)              0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 1024)              984064
#
#  dense_7 (Dense)             (None, 1024)              1049600
#
#  dense_8 (Dense)             (None, 512)               524800
#
#  classification (Dense)      (None, 20)                10260
#
# =================================================================
# Total params: 5,565,076
# Trainable params: 5,540,676
# Non-trainable params: 24,400
# _________________________________________________________________

# %%
EPOCHS = 5

history = model.fit(train_X, train_labels, epochs=EPOCHS,
                    validation_data=(valid_X, valid_labels), batch_size=100, shuffle=True)
# Out:
# Epoch 1/5
# 450/450 [==============================] - 254s 546ms/step - loss: 1.6249 - accuracy: 0.5169 - val_loss: 1.3521 - val_accuracy: 0.5845
# Epoch 2/5
# 450/450 [==============================] - 243s 541ms/step - loss: 0.7037 - accuracy: 0.7706 - val_loss: 1.0286 - val_accuracy: 0.6880
# Epoch 3/5
# 450/450 [==============================] - 243s 541ms/step - loss: 0.5023 - accuracy: 0.8358 - val_loss: 0.7124 - val_accuracy: 0.7765
# Epoch 4/5
# 450/450 [==============================] - 243s 540ms/step - loss: 0.3901 - accuracy: 0.8744 - val_loss: 0.5418 - val_accuracy: 0.8257
# Epoch 5/5
# 450/450 [==============================] - 244s 542ms/step - loss: 0.3140 - accuracy: 0.8972 - val_loss: 0.4191 - val_accuracy: 0.8673

# %%
test_images = preprocess_image_input(test_images)
results = model.evaluate(test_images, test_labels)
test = model.predict(test_images)
print(results[1])
# Out:
# 313/313 [==============================] - 12s 34ms/step - loss: 0.5454 - accuracy: 0.8289
# 313/313 [==============================] - 11s 31ms/step
# 0.8288999795913696

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Test 5')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])
plt.grid()
plt.show()
